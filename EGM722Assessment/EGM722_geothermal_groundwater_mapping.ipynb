# %% [markdown]
# EGM722 Programming for GIS and Remote Sensing Assessment 2
#
# Title: Mapping geothermal energy opportunity in relation to groundwater and environmental constraints in Northern Ireland using Python.
# Aim: This project maps geothermal potential and groundwater constraints in Northern Ireland using Python GIS tools.

# %% [markdown]
# 1 Import Python libraries

# %% [markdown]
# 2 Set file paths

# %% [markdown]
# 3 Set Coordinate Reference System (CRS)

# %% [markdown]
# 4 Load datasets

# %% [markdown]
# 5 Exploratory data analysis

# %% [markdown]
# 5.1 Inspect the structure of the data

# %% [markdown]
# 5.2 Inspect the data

# %% [markdown]
# 5.3 Summary statistics

# %% [markdown]
# 5.4 Transform the data

# %% [markdown]
# 5.5 Inspect data types and perform type casting

# %% [markdown]
# 6 Data cleaning

# %% [markdown]
# 7 Feature selection

# %% [markdown]
# 8 Check for missing data

# %% [markdown]
# 9 Save the transformed, cleaned, and standardised data

# %% [markdown]
# 10 Reproject data to the same CRS

# %% [markdown]
# 11 Clip datasets to Northern Ireland

# %% [markdown]
# 12 Spatial analysis

# %% [markdown]
# 13 Output map

# %% [markdown]
# 14 Interactive map

# %% [markdown]
# 15 Export outputs

# %% [markdown]
# 16 Conclusions and limitations
